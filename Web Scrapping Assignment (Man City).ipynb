# %%
#conda install beautifulsoup4 lxml requests pillow
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup
from PIL import Image # pillow package (Python Image Library)
import io

# %%
url = 'https://www.mancity.com/players/mens'
#https://www.mancity.com/players/mens
r = requests.get(url)  #get all the data from website
r.text[:100]
# Out:
# '\n<!DOCTYPE html>\n<html class="no-js" lang="en" dir="ltr">\n<head>\n<base href="/" />\n<meta charset="ut'

# %%
s = BeautifulSoup(r.text, 'lxml') #convert to lxml file
type(s)
# Out:
# bs4.BeautifulSoup

# %%
#prettify to be easy to read or organised
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="app-id=416127886" name="apple-itunes-app"/>
#   <meta content="UK South" name="Az-Region-Id"/>
#   <title>
#    Manchester City Squad Players
#   </title>
#   <script type="text/javascript">
#    window.currentCulture = 'en';
#   </script>
#   <script type="text/javascript">
#    var sdkInstance="appInsightsSDK";window[sdkInstance]="appInsights";var aiName=window[sdkInstance],aisdk=window[aiName]||function(e){function n(e){t[e]=function(){var n=arguments;t.queue.push(function(){t[e].apply(t,n)})}}var t={config:e};t.initialize=!0;var i=document,a=window;setTimeout(function(){var n=i.createElement("script");n.src=e.url||"https://az416426.vo.msecnd.net/scripts/b/ai.2.min.js",i.getElementsByTagName("script")[0].parentNode.appendChild(n)});try{t.cookie=i.cookie}catch(e){}t.queue=[],t.version=2;for(var r=["Event","PageView","Exception","Trace","DependencyData","Metric","PageViewPerformance"];r.length;)n("track"+r.pop());n("startTrackPage"),n("stopTrackPage");var s="Track"+r[0];if(n("start"+s),n("stop"+s),n("addTelemetryInitializer"),n("setAuthenticatedUserContext"),n("clearAuthenticatedUserContext"),n("flush"),!(!0===e.disableExceptionTracking||e.extensionConfig&&e.extensionConfig.ApplicationInsightsAnalytics&&!0===e.extensionConfig.ApplicationInsightsAnalytics.disableExceptionTracking)){n("_"+(r="onerror"));var o=a[r];a[r]=function(e,n,i,a,s){var c=o&&o(e,n,i,a,s);return!0!==c&&t["_"+r]({message:e,url:n,lineNumber:i,columnNumber:a,error:s}),c},e.autoExceptionInstrumented=!0}return t}(
# {
#   connectionString: 'InstrumentationKey=f9cf5ba3-d7ce-4268-8ceb-2b7f76631075'
# });
#
# window[aiName]=aisdk,aisdk.queue&&0===aisdk.queue.length&&aisdk.trackPageView({});
#   </script>
#   <link href="https://www.mancity.com/players/mens" hreflang="en-gb" rel="alternate"/>
#   <link href="https://ar.mancity.com/players/mens" hreflang="ar-ae" rel="alternate"/>
#   <link href="https://fr.mancity.com/players/mens" hreflang="fr-fr" rel="alternate"/>
#   <link href="https://id.mancity.com/players/mens" hreflang="id-id" rel="alternate"/>
#   <link href="https://kr.mancity.com/players/mens" hreflang="ko-kr" rel="alternate"/>
#   <link href="https://pt.mancity.com/players/mens" hreflang="pt-pt" rel="alternate"/>
#   <link href="https://es.mancity.com/players/mens" hreflang="es-es" rel="alternate"/>
#   <link href="https://th.mancity.com/players/mens" hreflang="th-th" rel="alternate"/>
#   <link href="https://www.mancity.com/players/mens" hreflang="en" rel="alternate"/>
#   <link href="https://www.mancity.com/players/mens" rel="canonical"/>
#   <meta content="Man City Men's, Women's, EDS, Academy squad players and Esports team members. Get the latest news, videos and social media for all the City roster. " name="description"/>
#   <meta content="Man City Players, manchester city squad, man city first team, mcwfc, man city women, man city mens, Manchester academy, manchester city esports" name="keywords"/>
#   <meta content="" name="author"/>
#   <meta content="Manchester City Squad Players" property="og:title"/>
#   <meta content="Article" property="og:type"/>
#   <meta content="" property="og:description"/>
#   <meta content="Manchester City FC" property="og:site_name"/>
#   <meta content="en-GB" property="og:locale"/>
#   <meta content="https://www.facebook.com/mancity" property="article:publisher"/>
#   <meta content="/players" property="og:url"/>
#   <meta content="" property="og:image"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="@mancity" property="twitter:site"/>
#   <meta content="" name="twitter:title"/>
#   <meta content="" name="twitter:description"/>
#   <meta content="@mancity" property="twitter:creator"/>
#   <meta content="www.mancity.com" property="twitter:domain"/>
#   <meta content="" name="twitter:image"/>
#   <meta content="CityApp" name="twitter:app:name:googleplay"/>
#   <meta content="com.mancity" name="twitter:app:id:googleplay"/>
#   <meta content="https://play.google.com/store/apps/details?id=com.mancity&amp;hl=en_GB" name="twitter:app:url:googleplay"/>
#   <meta content="United Kingdom" name="twitter:app:country"/>
#   <meta content="CityApp" name="twitter:app:name:iphone"/>
#   <meta content="416127886" name="twitter:app:id:iphone"/>
#   <meta content="https://itunes.apple.com/gb/app/cityapp-man-city-official-app/id416127886" name="twitter:app:url:iphone"/>
#   <meta content="208411345454" property="fb:pages"/>
#   <meta content="145679535467968" property="fb:pages"/>
#   <meta content="377398868991572" property="fb:pages"/>
#   <meta content="118855774845786" property="fb:pages"/>
#   <meta content="119435464813984" property="fb:pages"/>
#   <script>
#    (function(w) {
#       var mcfcPageviewDatalayer = {
#         "idm_id": getCookie('g_uid'),
#         "google_cookie": getCookie('_ga'),
#         "mixpanel_id": "mp_576d86ed553271a6b1a10fa9fc89cb39_mixpanel",
#         "user_language": "en",
#         "user_type": (getCookie('g_uid') ? 'logged': 'not_logged'),
#         "device_language": null,
#         "device": "web",
#         "environment": "production",
#         "team": "mens",
#         "previous_page": null,
#         "content_type": "landing",
#         "page_title": "manchester_city_squad_players",
#         "real_url": "https://www.mancity.com/players/mens",
#         "clean_url": "https://www.mancity.com/players/mens",
#         "opta_id": "43",
#         "opta_type": "player",
#         "content_id": "db255c1a-f701-4a27-aa0f-a40daa3ad666"
#       };
#
#       mcfcPageviewDatalayer.user_language = getUserLang();
#
#       function getUserLang() {
#           var userSession = localStorage.getItem('UserSession');
#           if (userSession) {
#             var user;
#             try {
#                 user = JSON.parse(userSession);
#             } catch (error) {
#                 console.error('Cant parse user info');
#             }
#             if (user && user.value && user.value.preferredLanguage) {
#                 return user.value.preferredLanguage;
#             }
#           }
#           return document.documentElement.lang;
#       }
#
#       function getCookie(name) {
#           var match = document.cookie.match(`(^|;) ?${name}=([^;]*)(;|$)`);
#           return match ? match[2] : null;
#       }
#
#       w.dataLayer = w.dataLayer || [];
#       w.dataLayer.push(mcfcPageviewDatalayer);
# }(window));
#   </script>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-P9PGGKP');
#   </script>
#   <link as="font" crossorigin="" href="https://web-assets.mancity.com/dist/fonts/Gotham/Gotham-Narrow-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://web-assets.mancity.com/dist/fonts/Gotham/Gotham-Narrow-Book.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://fonts.mancity.com/fonts/Kippax/KippaxModern-CndBd.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://fonts.mancity.com/fonts/Kippax/KippaxModern-CndxBd.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://fonts.mancity.com/fonts/Kippax/KippaxModern-Rg.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://fonts.mancity.com/fonts/Kippax/KippaxModern-Bd.woff2" rel="preload" type="font/woff2"/>
#   <link as="image" crossorigin="" href="https://web-assets.mancity.com/dist/images/man-city-loader.gif" rel="preload"/>
#   <link href="https://web-assets.mancity.com/dist/styles/main-ltr.css?v=Prod_250" rel="stylesheet"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="https://web-assets.mancity.com/dist/statics/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://web-assets.mancity.com/dist/statics/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://web-assets.mancity.com/dist/statics/android-icon-512x512.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://web-assets.mancity.com/dist/statics/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://web-assets.mancity.com/dist/statics/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://web-assets.mancity.com/dist/statics/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://web-assets.mancity.com/dist/statics/manifest.json" rel="manifest"/>
#   <meta content="#98C5E9" name="msapplication-TileColor"/>
#   <meta content="/dist/statics/ms-icon-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#98C5E9" name="theme-color"/>
#   <link href="https://amp.mancity.com/players/mens" rel="amphtml"/>
#   <script>
#    function applyImageFallback(e) { e.src = "data:image/svg+xml,%3Csvg xmlns='http://www.w3.org/2000/svg' version='1.1' viewBox='0 0 500 500' preserveAspectRatio='xMinYMin meet'%3E%3Ccircle cx='250' cy='250' r='230' fill='%23ededed' /%3E%3C/svg%3E", e.srcset = "", e.alt = "No Image", e.title = "No Image", e.className += " failed-to-load" } function markAsImgLoadFailed(e) { e.className += " failed-to-load" } document.documentElement.classList.remove("no-js"); document.documentElement.classList.add("js");
#   </script>
#  </head>
#  <body class="" itemscope="" itemtype="http://schema.org/WebPage">
#   <div class="js-banner-install-app banner-install-app">
#    <button class="js-btn-close-install-banner banner-install-app__close">
#     <svg aria-hidden="true" role="presentation">
#      <use xlink:href="#icon-close">
#      </use>
#     </svg>
#    </button>
#    <div class="banner-install-app__logo">
#     <img alt="Manchester City FC" class="banner-install-app__logo-img" height="53" src="/dist/images/logos/crest.svg" width="53"/>
#    </div>
#    <div class="banner-install-app__description">
#     <span class="banner-install-app__app-name">
#      Manchester City Official App
#     </span>
#     <span class="banner-install-app__app-pub">
#      Manchester City FC Ltd
#     </span>
#    </div>
#    <button class="js-btn-install-app banner-install-app__btn-install">
#     View
#    </button>
#   </div>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P9PGGKP" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="mc-page">
#    <header class="js-main-header mc-header mc-header--sticky">
#     <aside aria-label="Top banner" class="mc-header__aside">
#     </aside>
#     <div class="mc-header__primary-wrapper">
#      <div class="mc-header__primary-container">
#       <a class="mc-header__logo" href="/">
#        <img alt="Manchester City FC" class="mc-header__logo-img" height="53" src="/dist/images/logos/crest.svg" width="53"/>
#       </a>
#       <nav class="js-header-primary-nav mc-header-primary-nav mc-header__primary-nav" role="main">
#        <ul class="js-header-primary-nav-list mc-header-primary-nav__list">
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="/news">
#           <span class="mc-header-primary-nav__text">
#            News
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="/citytv/">
#           <span class="mc-header-primary-nav__text">
#            Video
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://www.mancity.com/citytv/city-plus">
#           <span class="mc-header-primary-nav__text">
#            CITY+
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <div class="js-header-fly-out mc-header-fly-out mc-header-primary-nav__fly-out">
#           <a aria-expanded="false" aria-haspopup="true" class="js-header-fly-trigger mc-header-fly-out__trigger mc-header-primary-nav__link mc-header-primary-nav__link--as-trigger" href="/fixtures">
#            <span class="mc-header-primary-nav__text">
#             Fixtures
#            </span>
#            <svg class="mc-header-primary-nav__chevron mc-header-fly-out__chevron" role="presentation">
#             <use xlink:href="#icon-chevron-down">
#             </use>
#            </svg>
#           </a>
#           <div class="js-header-drop-down mc-header-fly-out__drop-down mc-header-primary-nav__drop-down">
#            <ul class="js-header-drop-down-list mc-header-fly-out__sub-list mc-header-primary-nav__sub-list">
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens">
#              <a class="mc-header-fly-out__sub-link" href="/fixtures">
#               <span class="mc-header-fly-out__sub-text">
#                Fixtures
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens">
#              <a class="mc-header-fly-out__sub-link" href="/results">
#               <span class="mc-header-fly-out__sub-text">
#                Results
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens">
#              <a class="mc-header-fly-out__sub-link" href="/tables">
#               <span class="mc-header-fly-out__sub-text">
#                Tables
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <div class="js-header-fly-out mc-header-fly-out mc-header-primary-nav__fly-out">
#           <a aria-expanded="false" aria-haspopup="true" class="js-header-fly-trigger mc-header-fly-out__trigger mc-header-primary-nav__link mc-header-primary-nav__link--as-trigger" href="https://www.mancity.com/tickets">
#            <span class="mc-header-primary-nav__text">
#             Tickets
#            </span>
#            <svg class="mc-header-primary-nav__chevron mc-header-fly-out__chevron" role="presentation">
#             <use xlink:href="#icon-chevron-down">
#             </use>
#            </svg>
#           </a>
#           <div class="js-header-drop-down mc-header-fly-out__drop-down mc-header-primary-nav__drop-down">
#            <ul class="js-header-drop-down-list mc-header-fly-out__sub-list mc-header-primary-nav__sub-list">
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/tickets">
#               <span class="mc-header-fly-out__sub-text">
#                Tickets &amp; Hospitality
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/memberships">
#               <span class="mc-header-fly-out__sub-text">
#                Memberships
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="cityzens,cityzensU13,anonymous">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/tours">
#               <span class="mc-header-fly-out__sub-text">
#                Tours
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://tickets.mancity.com/crmdetails.aspx">
#               <span class="mc-header-fly-out__sub-text">
#                Manage my tickets
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/help-and-support">
#               <span class="mc-header-fly-out__sub-text">
#                Help and Support
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/concerts">
#               <span class="mc-header-fly-out__sub-text">
#                Concerts
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/tickets/season-tickets">
#               <span class="mc-header-fly-out__sub-text">
#                Season Tickets
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://shop.mancity.com">
#           <span class="mc-header-primary-nav__text">
#            Shop
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13" data-selected="true">
#          <a class="mc-header-primary-nav__link mc-header-primary-nav__link--underline" href="/players/mens">
#           <span class="mc-header-primary-nav__text">
#            Players
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <div class="js-header-fly-out mc-header-fly-out mc-header-primary-nav__fly-out">
#           <a aria-expanded="false" aria-haspopup="true" class="js-header-fly-trigger mc-header-fly-out__trigger mc-header-primary-nav__link mc-header-primary-nav__link--as-trigger" href="/club">
#            <span class="mc-header-primary-nav__text">
#             Club
#            </span>
#            <svg class="mc-header-primary-nav__chevron mc-header-fly-out__chevron" role="presentation">
#             <use xlink:href="#icon-chevron-down">
#             </use>
#            </svg>
#           </a>
#           <div class="js-header-drop-down mc-header-fly-out__drop-down mc-header-primary-nav__drop-down">
#            <ul class="js-header-drop-down-list mc-header-fly-out__sub-list mc-header-primary-nav__sub-list">
#             <li class="mc-header-fly-out__sub-item" data-access-role="cityzens,anonymous">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/club">
#               <span class="mc-header-fly-out__sub-text">
#                Club
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/etihad-stadium">
#               <span class="mc-header-fly-out__sub-text">
#                Etihad Stadium
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous,cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/etihad-stadium-feasibility-studies">
#               <span class="mc-header-fly-out__sub-text">
#                Etihad Stadium Feasibility Studies
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="/manchester-city-women">
#           <span class="mc-header-primary-nav__text">
#            Man City Women
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="cityzens,anonymous,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://www.mancity.com/fans">
#           <span class="mc-header-primary-nav__text">
#            Fans
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="/community">
#           <span class="mc-header-primary-nav__text">
#            Community
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="cityzens,anonymous,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://www.mancity.com/club/manchester-city-history">
#           <span class="mc-header-primary-nav__text">
#            History
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://www.mancity.com/learn-football">
#           <span class="mc-header-primary-nav__text">
#            Learn Football
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://www.mancity.com/esports">
#           <span class="mc-header-primary-nav__text">
#            Esports
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://www.mancity.com/help">
#           <span class="mc-header-primary-nav__text">
#            Help &amp; Support
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item mc-header-primary-nav__item" data-access-role="anonymous,cityzens,cityzensU13">
#          <a class="mc-header-primary-nav__link" href="https://www.mancity.com/cityplay">
#           <span class="mc-header-primary-nav__text">
#            CITYPLAY
#           </span>
#          </a>
#         </li>
#         <li class="js-header-primary-nav-item js-header-primary-nav-more mc-header-primary-nav__item is-invisible">
#          <div class="js-header-fly-out mc-header-fly-out mc-header-primary-nav__fly-out">
#           <a aria-expanded="false" aria-haspopup="true" class="js-header-fly-trigger mc-header-fly-out__trigger mc-header-primary-nav__link mc-header-primary-nav__link--as-trigger" href="#">
#            <span class="mc-header-primary-nav__text">
#             More
#            </span>
#            <svg class="mc-header-primary-nav__chevron mc-header-fly-out__chevron" role="presentation">
#             <use xlink:href="#icon-chevron-down">
#             </use>
#            </svg>
#           </a>
#           <div class="js-header-drop-down mc-header-fly-out__drop-down mc-header-primary-nav__drop-down">
#            <ul class="js-header-drop-down-list js-header-primary-nav-more-list mc-header-fly-out__sub-list mc-header-primary-nav__sub-list">
#             <li class="mc-header-fly-out__sub-item" data-access-role="[[accessRole]]">
#              <a class="mc-header-fly-out__sub-link [[className]]" href="[[href]]">
#               <span class="mc-header-fly-out__sub-text">
#                [[text]]
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#        </ul>
#       </nav>
#       <nav aria-label="Secondary navigation" class="js-header-secondary-nav mc-header-secondary-nav mc-header__secondary-nav">
#        <ul class="mc-header-secondary-nav__list is-hidden">
#         <li class="mc-header-secondary-nav__item mc-header-secondary-nav__choose-lang">
#          <button class="js-locale-selector mc-header-locale-selector" title="locale-selector" type="button">
#           <svg class="mc-header-locale-selector__icon" role="presentation">
#            <use xlink:href="#icon-i18n">
#            </use>
#           </svg>
#           <span class="mc-header-locale-selector__text">
#            en
#           </span>
#          </button>
#         </li>
#         <li class="mc-header-secondary-nav__item mc-header-secondary-nav__log-in" data-access-role="anonymous">
#          <a class="mc-header-log-in" data-auto-return="true" href="/account/login">
#           <span class="mc-header-log-in__text">
#            Login
#           </span>
#           <span class="mc-header-log-in__thumbnail-wrapper">
#            <svg class="mc-header-log-in__user-icon" role="presentation">
#             <use xlink:href="#icon-avatar">
#             </use>
#            </svg>
#           </span>
#          </a>
#         </li>
#         <li class="mc-header-secondary-nav__item mc-header-secondary-nav__my-account" data-access-role="cityzens,cityzensU13">
#          <div class="js-header-fly-out mc-header-fly-out mc-header-my-account">
#           <a aria-expanded="false" aria-haspopup="true" class="js-header-fly-trigger mc-header-my-account__link mc-header-fly-out__trigger" href="https://www.mancity.com/my-account?nopartners">
#            <span class="js-header-user-thumbnail mc-header-my-account__thumbnail-wrapper">
#             <svg class="mc-header-my-account__user-icon" role="presentation">
#              <use xlink:href="#icon-avatar">
#              </use>
#             </svg>
#             <img alt="User Thumbnail" class="mc-header-my-account__user-pic"/>
#            </span>
#            <svg class="mc-header-my-account__chevron mc-header-fly-out__chevron" role="presentation">
#             <use xlink:href="#icon-chevron-down">
#             </use>
#            </svg>
#           </a>
#           <div class="js-header-drop-down mc-header-my-account__drop-down mc-header-fly-out__drop-down">
#            <ul class="js-header-drop-down-list mc-header-my-account__sub-list mc-header-fly-out__sub-list">
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous">
#              <a class="mc-header-fly-out__sub-link" href="/account/login">
#               <span class="mc-header-fly-out__sub-text">
#                Login
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="anonymous">
#              <a class="mc-header-fly-out__sub-link" href="/account/register">
#               <span class="mc-header-fly-out__sub-text">
#                Join
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://www.mancity.com/my-account?nopartners">
#               <span class="mc-header-fly-out__sub-text">
#                My Account
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="cityzens">
#              <a class="mc-header-fly-out__sub-link" data-auto-return="true" href="https://cityzens.mancity.com/">
#               <span class="mc-header-fly-out__sub-text">
#                My Cityzens
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="https://kids.mancity.com/">
#               <span class="mc-header-fly-out__sub-text">
#                Junior Cityzens
#               </span>
#              </a>
#             </li>
#             <li class="mc-header-fly-out__sub-item" data-access-role="cityzens,cityzensU13">
#              <a class="mc-header-fly-out__sub-link" href="/account/logout">
#               <span class="mc-header-fly-out__sub-text">
#                Logout
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </li>
#         <li class="mc-header-secondary-nav__item mc-header-secondary-nav__live-blog-counter-wrapper js-live-blog-counter">
#          <a class="mc-header-secondary-nav__live-blog-counter-link" href="#">
#           0
#          </a>
#         </li>
#        </ul>
#        <div class="mc-header-secondary-nav__mob-nav">
#         <button class="js-open-mobile mc-header-open-mobile" title="mobile-menu" type="button">
#          <svg class="mc-header-open-mobile__icon" role="presentation">
#           <use xlink:href="#icon-hamburger-button">
#           </use>
#          </svg>
#         </button>
#        </div>
#       </nav>
#      </div>
#     </div>
#    </header>
#    <main class="mc-main-content">
#     <header aria-label="Page header" class="js-sub-header sub-header" data-content-type="landing" data-team="Mancity.Platform.Website.Models.Players.PlayersViewModel">
#      <div class="container">
#       <div class="sub-header__primary">
#        <h1 class="sub-header__heading">
#         Players
#        </h1>
#        <div class="sub-header__sponsor">
#         <span class="sub-header__sponsor-link">
#          <span class="sub-header__sponsor-text shown-lg">
#           Presented by
#          </span>
#          <img alt="Puma" class="sub-header__sponsor-img" height="20" src="/dist/images/puma_crest.png" title="Puma" width="83"/>
#         </span>
#        </div>
#       </div>
#       <nav aria-label="Navigation between teams">
#        <ul class="mc-tabs-nav js-scrollable-tabs-nav">
#         <li class="mc-tabs-nav__item js-tabs-nav-item js-is-active">
#          <a class="mc-tabs-nav__item-link mc-tabs-nav__item-link--active" href="/players/mens">
#           <span class="mc-tabs-nav__item-link-text">
#            Men’s Team
#           </span>
#           <span class="mc-tabs-nav__item-link-text mc-tabs-nav__item-link-text--short">
#            Men’s Team
#           </span>
#          </a>
#         </li>
#         <li class="mc-tabs-nav__item js-tabs-nav-item">
#          <a class="mc-tabs-nav__item-link" href="/players/womens">
#           <span class="mc-tabs-nav__item-link-text">
#            Women’s Team
#           </span>
#           <span class="mc-tabs-nav__item-link-text mc-tabs-nav__item-link-text--short">
#            Women’s
#           </span>
#          </a>
#         </li>
#         <li class="mc-tabs-nav__item js-tabs-nav-item">
#          <a class="mc-tabs-nav__item-link" href="/players/eds">
#           <span class="mc-tabs-nav__item-link-text">
#            EDS
#           </span>
#           <span class="mc-tabs-nav__item-link-text mc-tabs-nav__item-link-text--short">
#            EDS
#           </span>
#          </a>
#         </li>
#         <li class="mc-tabs-nav__item js-tabs-nav-item">
#          <a class="mc-tabs-nav__item-link" href="/players/academy">
#           <span class="mc-tabs-nav__item-link-text">
#            Academy
#           </span>
#           <span class="mc-tabs-nav__item-link-text mc-tabs-nav__item-link-text--short">
#            Academy
#           </span>
#          </a>
#         </li>
#        </ul>
#       </nav>
#      </div>
#     </header>
#     <script type="application/ld+json">
#      {
#     "@context":"http://schema.org",
#     "@type":"SportsTeam",
#     "name":"Manchester City",
#     "sport":"Football",
#     "URL":"https://www.mancity.com",
#     "logo":"https://mediacdn.mancity.com/cf/media/yzscd2rf/manchester_city_fc_badge.png",
#     "alternateName":"Man City",
#     "foundingDate":"1894-04-16",
#     "telephone":"+44 161 444 1894",
#     "sponsor":"Etihad Airways",
#     "sameAs":[
#       "https://www.youtube.com/channel/UCkzCjdRMrW2vXLx8mvPVLdQ",
#       "https://www.instagram.com/mancity/",
#       "https://twitter.com/ManCity",
#       "https://www.facebook.com/mancity"
#     ],
#     "brand":{
#       "@type":"Organization",
#       "name":"Manchester City",
#       "logo":"https://mediacdn.mancity.com/cf/media/yzscd2rf/manchester_city_fc_badge.png",
#       "award":[
#         "FA Cup Winners",
#         "League Cup Winners",
#         "European Cup Winners Cup Winners",
#         "Charity Shield Winners",
#         "FA Youth Cup Winners",
#         "FA Community Winners",
#         "Premier League Champions",
#         "Division One Champions",
#         "Division Two Champions",
#         "FA Women's Super League Champions",
#         "Continental Tyres Cup Winners",
#         "FA Women's Cup Winners"
#       ]
#     },
#     "address":{
#       "@type":"PostalAddress",
#       "addressLocality":"Manchester",
#       "streetAddress":"Etihad Stadium, Etihad Campus"
#     },
#     "memberOf":[
#       {
#         "@type":"SportsOrganization",
#         "name":"Premier League"
#       },
#       {
#         "@type":"SportsOrganization",
#         "name":"UEFA Champions League"
#       },
#       {
#         "@type":"SportsOrganization",
#         "name":"Carabau Cup"
#       },
#       {
#         "@type":"SportsOrganization",
#         "name":"The FA Cup"
#       }
#     ],
#     "coach":{
#       "@type":"Person",
#       "name":"Pep Guardiola"
#     },
# "members" :
#         [
#
#                 {
#                     "@type":"OrganizationRole",
#                     "roleName":"Goalkeepers",
#                     "members":[
#
#                         {
#                             "@type":"Person",
#                             "givenName":"Zack",
#                             "familyName":"Steffen",
#                             "birthDate":"2 April 1995",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"United States of America, Coatesville"
#                             },
#                             "height":"0 centimeters",
#                             "image":"https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png",
#                             "identifier":"13",
#                             "sameAs": [
#                                   ""
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/zack-steffen"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Stefan",
#                             "familyName":"Ortega Moreno",
#                             "birthDate":"6 November 1992",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"Germany, Hofgeismar"
#                             },
#                             "height":"185 centimeters",
#                             "image":"https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png",
#                             "identifier":"18",
#                             "sameAs": [
#                                   "" , "https://www.instagram.com/stefan.ortega1"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/stefan-ortega-moreno"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"",
#                             "familyName":"Ederson",
#                             "birthDate":"17 August 1993",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"Brazil, Osasco"
#                             },
#                             "height":"188 centimeters",
#                             "image":"https://www.mancity.com/meta/media/xg0cuprp/ederson.png",
#                             "identifier":"31",
#                             "sameAs": [
#                                   "https://twitter.com/edersonmoraes93" , "https://www.instagram.com/ederson93"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/ederson"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Scott",
#                             "familyName":"Carson",
#                             "birthDate":"25 September 1985",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"England, Whitehaven"
#                             },
#                             "height":"0 centimeters",
#                             "image":"https://www.mancity.com/meta/media/srpgqlct/scott-carson.png",
#                             "identifier":"33",
#                             "sameAs": [
#                                   ""
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/scott-carson"
#                       }
#                     ]
#                 },
#                 {
#                     "@type":"OrganizationRole",
#                     "roleName":"Defenders",
#                     "members":[
#
#                         {
#                             "@type":"Person",
#                             "givenName":"Kyle",
#                             "familyName":"Walker",
#                             "birthDate":"28 May 1990",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"England, Sheffield"
#                             },
#                             "height":"178 centimeters",
#                             "image":"https://www.mancity.com/meta/media/qhmhkd01/kyle-walker.png",
#                             "identifier":"2",
#                             "sameAs": [
#                                   "https://twitter.com/kylewalker2" , "https://www.instagram.com/kylewalker2"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/kyle-walker"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Ruben",
#                             "familyName":"Dias",
#                             "birthDate":"14 May 1997",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"Portugal, Amadora, Lisbon"
#                             },
#                             "height":"187 centimeters",
#                             "image":"https://www.mancity.com/meta/media/yowlxkfa/ruben-dias.png",
#                             "identifier":"3",
#                             "sameAs": [
#                                   "https://twitter.com/rubendias" , "https://www.instagram.com/rubendias"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/ruben-dias"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"John",
#                             "familyName":"Stones",
#                             "birthDate":"28 May 1994",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"England, Hemsworth"
#                             },
#                             "height":"188 centimeters",
#                             "image":"https://www.mancity.com/meta/media/4cicyu5v/john-stones.png",
#                             "identifier":"5",
#                             "sameAs": [
#                                   "" , "https://www.instagram.com/johnstonesofficial"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/john-stones"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Nathan",
#                             "familyName":"Ake",
#                             "birthDate":"18 February 1995",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"Netherlands, The Hague"
#                             },
#                             "height":"180 centimeters",
#                             "image":"https://www.mancity.com/meta/media/oelcevzg/nathan-ake-r.png",
#                             "identifier":"6",
#                             "sameAs": [
#                                   "https://twitter.com/NathanAke" , "https://www.instagram.com/nathanake"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/nathan-ake"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"João",
#                             "familyName":"Cancelo",
#                             "birthDate":"27 May 1994",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"Portugal, Barreiro"
#                             },
#                             "height":"0 centimeters",
#                             "image":"https://www.mancity.com/meta/media/pm3b0zop/joao-cancelo.png",
#                             "identifier":"7",
#                             "sameAs": [
#                                   "" , "https://www.instagram.com/jpcancelo"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/joao-cancelo"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Aymeric",
#                             "familyName":"Laporte",
#                             "birthDate":"27 May 1994",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"France, Agen"
#                             },
#                             "height":"191 centimeters",
#                             "image":"https://www.mancity.com/meta/media/3ccfwpn5/aymeric-laporte.png",
#                             "identifier":"14",
#                             "sameAs": [
#                                   "https://twitter.com/laporte" , "https://www.instagram.com/a.laporte"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/aymeric-laporte"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Sergio",
#                             "familyName":"Gomez",
#                             "birthDate":"4 September 2000",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"Spain, Badalona"
#                             },
#                             "height":"171 centimeters",
#                             "image":"https://www.mancity.com/meta/media/2jkdz4bv/sergio-gomez-h-s-cut.png",
#                             "identifier":"21",
#                             "sameAs": [
#                                   "https://twitter.com/sergiogm_10" , "https://www.instagram.com/sergiogm_10"
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/sergio-gomez"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Manuel",
#                             "familyName":"Akanji",
#                             "birthDate":"19 July 1995",
#                             "birthPlace":{
#                                 "@type":"Place",
#                                 "address":"Switzerland, Wiesendangen"
#                             },
#                             "height":"188 centimeters",
#                             "image":"https://www.mancity.com/meta/media/akzl24xy/akanji-cut-out.png",
#                             "identifier":"25",
#                             "sameAs": [
#                                   ""
#                             ],
#                             "memberOf": {
#                               "@type":"SportsOrganization",
#                               "name":"Manchester City – mens"
#                             },
#                             "url":"https://www.mancity.com//players/manuel-akanji"
#                       },
#                         {
#                             "@type":"Person",
#                             "givenName":"Rico",
#                             "familyName":"Lewis",
#                             "birthDate":"21 November 2004",
#                             "birthPlace":{
#                                 "@type":"Place",
# ...
#     </path>
#    </symbol>
#    <symbol id="icon-email" viewbox="0 0 56 56">
#     <defs>
#      <path d="M0 0h48v31H0z" id="a">
#      </path>
#     </defs>
#     <g fill="none" fill-rule="evenodd" transform="translate(4 12)">
#      <mask fill="#fff" id="b">
#       <use xlink:href="#a">
#       </use>
#      </mask>
#      <path d="M0 2.116v27.252C0 30.273.714 31 1.6 31h44.8c.886 0 1.6-.727 1.6-1.632V2.116L25.05 22.434a1.576 1.576 0 01-2.1 0L0 2.116zM2.475 0L24 19.044 45.525 0H2.475z" fill="currentColor" mask="url(#b)">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-chevron-down" viewbox="0 0 16 16">
#     <path d="M12.999 6L8 11 3 6" fill="none" fill-rule="evenodd" stroke="currentColor" stroke-width="1.5">
#     </path>
#    </symbol>
#    <symbol id="icon-tooltip" viewbox="0 0 24 24">
#     <defs>
#      <circle cx="12" cy="12" id="a" r="12">
#      </circle>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#      <mask fill="#fff" id="b">
#       <use xlink:href="#a">
#       </use>
#      </mask>
#      <circle cx="12" cy="12" r="11" stroke="#001838" stroke-width="2">
#      </circle>
#      <text fill="#001838" font-family="Helvetica-Bold, Helvetica" font-size="16" font-weight="bold" x="7" y="18">
#       ?
#      </text>
#     </g>
#    </symbol>
#    <symbol id="icon-trophy" viewbox="0 0 32 32">
#     <defs>
#      <path d="M7 0L4.667 2.5 7 5H0V0h7z" id="atrophy">
#      </path>
#      <path d="M7 0L4.667 2.5 7 5H0V0h7z" id="btrophy">
#      </path>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#      <path d="M10 19h12v2H10zm2 2h8v2h-8zm3 2h2v2h-2z" fill="#001838" fill-rule="nonzero">
#      </path>
#      <path d="M15 22h2v6h-2z" fill="#001838" fill-rule="nonzero">
#      </path>
#      <path d="M12 27h8a2 2 0 012 2v2H10v-2a2 2 0 012-2z" fill="#001838" fill-rule="nonzero">
#      </path>
#      <path d="M23 5h6v10l-5 3M9 5H3v10l5 3" stroke="#001838" stroke-linecap="round" stroke-linejoin="round" stroke-width="2">
#      </path>
#      <path d="M6 15h20v6H6z" fill="#FFF" fill-rule="nonzero">
#      </path>
#      <use fill="#3BD6FF" fill-rule="nonzero" transform="rotate(90 9.5 11.5)" xlink:href="#atrophy">
#      </use>
#      <path d="M7 12.435v5.217c0 1.301.688 3.13 3.375 5.218C12.166 24.26 14.041 25.304 16 26V2H7v10.435zm18 0v5.217c0 1.301-.688 3.13-3.375 5.218C19.834 24.26 17.959 25.304 16 26V2h9v10.435z" fill="#001838" fill-rule="nonzero">
#      </path>
#      <use fill="#3BD6FF" fill-rule="nonzero" transform="rotate(90 9.5 11.5)" xlink:href="#btrophy">
#      </use>
#     </g>
#    </symbol>
#    <symbol id="icon-school" viewbox="0 0 32 32">
#     <defs>
#      <path d="M7 0L4.667 2.5 7 5H0V0h7z" id="aschool">
#      </path>
#     </defs>
#     <g fill="none">
#      <path d="M0 18h32v14H0z" fill="#001838">
#      </path>
#      <path d="M7 14h18v16H7z" fill="#001838">
#      </path>
#      <path d="M13 25h6v6h-6z" fill="#FFF">
#      </path>
#      <path d="M15.5 25h1v6h-1z" fill="#001838">
#      </path>
#      <path d="M27 21h3v2h-3zM7 21h4v2H7zm6 0h6v2h-6zm8 0h4v2h-4zM2 21h3v2H2zm25 4h3v2h-3zM7 25h4v2H7zm14 0h4v2h-4zM2 25h3v2H2z" fill="#FFF">
#      </path>
#      <path d="M7 14l9-8 9 8z" fill="#001838">
#      </path>
#      <use fill="#3BD6FF" transform="translate(16)" xlink:href="#aschool">
#      </use>
#      <circle cx="16" cy="14" fill="#FFF" r="3">
#      </circle>
#      <path d="M15.5 0h1v8h-1z" fill="#001838">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-careers" viewbox="0 0 32 32">
#     <defs>
#      <path d="M0 0h16v6H0z" id="a">
#      </path>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#      <rect fill="#001838" fill-rule="nonzero" height="22" rx="1" stroke="#001838" stroke-width="2" transform="translate(0 6)" width="30" x="1" y="1">
#      </rect>
#      <path d="M14 21v2h4v-2h-4z" fill="#001838" fill-rule="nonzero" stroke="#3BD6FF" stroke-width="2">
#      </path>
#      <path d="M15 19h2v3h-2z" fill="#001838" fill-rule="nonzero">
#      </path>
#      <g transform="translate(8 1)">
#       <mask fill="#fff" id="b">
#        <use xlink:href="#a">
#        </use>
#       </mask>
#       <rect height="5" mask="url(#b)" rx="1" stroke="#001838" stroke-width="2" width="12" x="2" y="2">
#       </rect>
#      </g>
#      <path d="M12 19H3c-2 0-3.333-1-4-3m21 3h9c2 0 3.333-1 4-3" stroke="#FFF" stroke-width="2">
#      </path>
#      <path d="M12 18h8v2h-8z" fill="#FFF" fill-rule="nonzero">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-download" viewbox="0 0 24 24">
#     <g fill="currentColor" fill-rule="evenodd">
#      <path d="M11.002 4v14h2V4z">
#      </path>
#      <path d="M17.36 12.232a1 1 0 011.28 1.536L12 19.302l-6.64-5.534a1 1 0 011.28-1.536L12 16.698l5.36-4.466zM2 18h2v6H2zm2 4h16v2H4zm16-4h2v6h-2z" fill-rule="nonzero">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-arrow-right" viewbox="0 0 16 16">
#     <g fill="currentColor" fill-rule="evenodd">
#      <path d="M0 8h14V6H0z">
#      </path>
#      <path d="M8.303 1.64A1 1 0 119.84.36L15.373 7 9.84 13.64a1 1 0 11-1.537-1.28L12.77 7 8.303 1.64z" fill-rule="nonzero">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-hamburger-button" viewbox="0 0 24 24">
#     <g fill="currentColor" fill-rule="evenodd">
#      <path d="M0 0h24v24H0z">
#      </path>
#      <path d="M2 5h20v2H2zm0 6h20v2H2zm0 6h20v2H2z" fill="#001838">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-flag" viewbox="0 0 24 24">
#     <path d="M14.3 6C12 3.7 8.3 3.7 6 5.9V4c0-.6-.4-1-1-1s-1 .4-1 1v17h2v-6.2c2.3-2.2 6-2.2 8.3.1 1.6 1.6 4.1 1.6 5.7 0V6c-1.5 1.5-4.1 1.6-5.7 0z" fill="currentColor" fill-rule="evenodd">
#     </path>
#    </symbol>
#    <symbol fill="none" id="icon-plus" viewbox="0 0 24 24">
#     <path clip-rule="evenodd" d="M11 11V4h2v7h7v2h-7v7h-2v-7H4v-2h7z" fill="currentColor" fill-rule="evenodd">
#     </path>
#    </symbol>
#    <symbol fill="none" id="icon-minus" viewbox="0 0 24 24">
#     <path clip-rule="evenodd" d="M4 13h16v-2H4v2z" fill="currentColor" fill-rule="evenodd">
#     </path>
#    </symbol>
#    <symbol fill="none" id="icon-smile" viewbox="0 0 24 24">
#     <path d="M3 12c0-4.969 4.024-9 8.99-9C16.968 3 21 7.033 21 12s-4.032 9-9.01 9C7.024 21 3 16.969 3 12z" stroke="currentColor" stroke-width="2">
#     </path>
#     <path d="M15.5 11c.83 0 1.5-.67 1.5-1.5S16.33 8 15.5 8 14 8.67 14 9.5s.67 1.5 1.5 1.5zm-7 0c.83 0 1.5-.67 1.5-1.5S9.33 8 8.5 8 7 8.67 7 9.5 7.67 11 8.5 11zm3.5 6.5c2.33 0 4.31-1.46 5.11-3.5H6.89c.8 2.04 2.78 3.5 5.11 3.5z" fill="currentColor">
#     </path>
#    </symbol>
#    <symbol fill="none" id="icon-image" viewbox="0 0 24 24">
#     <rect height="16" rx="1" stroke="currentColor" stroke-width="2" width="18" x="3" y="4">
#     </rect>
#     <path d="M3 17c.5-.833 1.5-2.5 3.5-2.5S9 16 11.5 16s4.045-3.136 5.5-3.5c2-.5 4 .5 4 2" stroke="currentColor" stroke-width="2">
#     </path>
#     <circle cx="9" cy="9" fill="currentColor" r="2">
#     </circle>
#    </symbol>
#    <symbol fill="none" id="icon-paperclip" viewbox="0 0 24 24">
#     <path d="M17 5v12c0 2.757-2.243 5-5 5s-5-2.243-5-5V5c0-1.654 1.346-3 3-3s3 1.346 3 3v9c0 .551-.449 1-1 1s-1-.449-1-1V6H9v8a3 3 0 106 0V5A5 5 0 005 5v12a7 7 0 1014 0V5h-2z" fill="currentColor">
#     </path>
#    </symbol>
#    <symbol fill="none" id="icon-social-like" viewbox="0 0 24 24">
#     <path clip-rule="evenodd" d="M20 8h-4.31l.41-3.62.03-.32c0-.41-.17-.79-.44-1.06L14.5 2 8.59 7.59C8.22 7.95 8 8.45 8 9v9c0 1.1.9 2 2 2h7c.83 0 1.54-.5 1.84-1.22l3.02-6.05c.09-.23.14-.47.14-.73v-2c0-1.1-.9-2-2-2zm0 4l-3 6h-7V9l4-3.7-.77 4.7H20v2zM6 9H2v11h4V9z" fill="currentColor" fill-rule="evenodd">
#     </path>
#    </symbol>
#    <symbol fill="none" id="icon-arrow-left" viewbox="0 0 24 24">
#     <path d="M20 12l-6 6-1.42-1.42L16.17 13H4V5h2v6h10.17l-3.59-3.58L14 6l6 6z" fill="currentColor">
#     </path>
#    </symbol>
#    <symbol id="icon-thumbtack" viewbox="0 0 1000 1000">
#     <path d="M10 989.7l388.5-308 155 164.8s64.7 17.6 68.7-31.3l-4-166.9 229.6-264.8 100-5.8s78.5-15.8 21.6-84.4L688.8 10.8S612.4 1 618.2 71.6v76.5L357.3 369.9l-160.8 9.7s-58.9 19.6-37.3 70.6l151.1 149.1L10 989.7z" fill="currentColor">
#     </path>
#    </symbol>
#    <symbol id="icon-info" viewbox="0 0 16 16">
#     <g fill="none" fill-rule="evenodd">
#      <circle cx="8" cy="8" fill="#2F3133" r="8">
#      </circle>
#      <path d="M7 7h2v6H7zm0-4h2v2H7z" fill="#FFF">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="right-chevron" viewbox="0 0 7 12">
#     <path d="M1 1l5 5-5 5" fill="none" fill-rule="evenodd" stroke="currentColor" stroke-width="1.5">
#     </path>
#    </symbol>
#    <symbol id="icon-play-button-electric-blue" viewbox="0 0 56 56">
#     <circle cx="28" cy="28" data-name="Oval 5" fill="#3bd6ff" id="Oval_5" r="28">
#     </circle>
#     <path d="M0 22V0l19.395 11z" data-name="Path 2 Copy 2" fill="#001838" id="Path_2_Copy_2" transform="translate(20.421 17)">
#     </path>
#    </symbol>
#    <symbol id="icon-gallery-electric-blue" viewbox="0 0 56 56">
#     <path d="M0 0h56v56H0z" data-name="Icons/Media/PictureSpecial background" fill="none" id="Icons_Media_PictureSpecial_background">
#     </path>
#     <circle cx="28" cy="28" data-name="Oval 5" fill="#3bd6ff" id="Oval_5" r="28">
#     </circle>
#     <path d="M3814.169-8224.5a2.171 2.171 0 01-2.168-2.169v-11.212a2.169 2.169 0 012.168-2.173h5.429a1.943 1.943 0 011.945-1.946h6.964a1.946 1.946 0 011.944 1.946h5.424a2.174 2.174 0 012.173 2.173v11.212a2.175 2.175 0 01-2.173 2.169zm4.343-7.777c0 3.219 2.918 5.833 6.51 5.833s6.515-2.614 6.515-5.833-2.923-5.833-6.515-5.833-6.51 2.616-6.51 5.831zm-4.343-4.859a.974.974 0 00.975.97h1.311a.972.972 0 00.97-.97.973.973 0 00-.97-.974h-1.311a.974.974 0 00-.975.971zm6.511 4.859a4.136 4.136 0 014.342-3.89 4.136 4.136 0 014.342 3.89 4.132 4.132 0 01-4.342 3.886 4.132 4.132 0 01-4.342-3.888z" data-name="Path 59992" fill="#001838" id="Path_59992" transform="translate(-3797.024 8261.252)">
#     </path>
#    </symbol>
#    <symbol id="icon-padlock-electric-blue" viewbox="0 0 56 56">
#     <circle cx="28" cy="28" data-name="Oval 5" fill="#3bd6ff" id="Oval_5" r="28">
#     </circle>
#     <g data-name="Page 1" fill="#001838" id="Page_1" transform="translate(19.272 16)">
#      <path d="M17.455 19.636H0v-8.727a1.092 1.092 0 011.091-1.091h1.124a4.288 4.288 0 01-.033-.546V6a6.007 6.007 0 016-6h1.09a6.007 6.007 0 016 6v3.272a4.465 4.465 0 01-.033.546h1.124a1.092 1.092 0 011.091 1.091v8.726zM8.181 3.272A2.73 2.73 0 005.455 6v3.272a3.018 3.018 0 00.054.546h6.437A3.02 3.02 0 0012 9.272V6a2.731 2.731 0 00-2.728-2.728z" data-name="Fill 1" id="Fill_1">
#      </path>
#      <path d="M0 0h17.455v1.091a1.094 1.094 0 01-1.091 1.091H1.091A1.094 1.094 0 010 1.091z" data-name="Fill 3" id="Fill_3" transform="translate(0 21.818)">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-play-button-electric-blue-small" viewbox="0 0 20 20">
#     <circle cx="10" cy="10" data-name="Oval 5" fill="#3bd6ff" id="Oval_5" r="10">
#     </circle>
#     <path d="M0 9V0l7.934 4.5z" data-name="Path 2 Copy 2" fill="#001838" id="Path_2_Copy_2" transform="translate(7.293 5.5)">
#     </path>
#    </symbol>
#    <symbol id="icon-gallery-electric-blue-small" viewbox="0 0 20 20">
#     <circle cx="10" cy="10" data-name="Oval 5" fill="#3bd6ff" id="Oval_5" r="10">
#     </circle>
#     <path d="M3813-8233.939a1 1 0 01-1-1v-5.165a1 1 0 011-1h2.5a.9.9 0 01.9-.9h3.208a.9.9 0 01.9.9h2.5a1 1 0 011 1v5.165a1 1 0 01-1 1zm2-3.583a2.858 2.858 0 003 2.687 2.86 2.86 0 003-2.687 2.861 2.861 0 00-3-2.687 2.859 2.859 0 00-3 2.687zm-2-2.239a.449.449 0 00.449.447h.6a.448.448 0 00.447-.447.448.448 0 00-.447-.448h-.6a.448.448 0 00-.449.447zm3 2.239a1.905 1.905 0 012-1.792 1.905 1.905 0 012 1.792 1.9 1.9 0 01-2 1.79 1.9 1.9 0 01-2-1.79z" data-name="Path 59996" fill="#001838" id="Path_59996" transform="translate(-3808.001 8247.971)">
#     </path>
#    </symbol>
#    <symbol id="icon-padlock-electric-blue-small" viewbox="0 0 20 20">
#     <circle cx="10" cy="10" data-name="Oval 5" fill="#3bd6ff" id="Oval_5" r="10">
#     </circle>
#     <g data-name="Page 1" fill="#001838" id="Page_1" transform="translate(6 4.5)">
#      <path d="M8 9H0V5a.5.5 0 01.5-.5h.515A1.965 1.965 0 011 4.25v-1.5A2.753 2.753 0 013.75 0h.5A2.753 2.753 0 017 2.75v1.5a2.047 2.047 0 01-.015.25H7.5A.5.5 0 018 5v4zM3.75 1.5A1.251 1.251 0 002.5 2.75v1.5a1.383 1.383 0 00.025.25h2.95a1.384 1.384 0 00.025-.25v-1.5A1.252 1.252 0 004.25 1.5z" data-name="Fill 1" id="Fill_1">
#      </path>
#      <path d="M0 0h8v.5a.5.5 0 01-.5.5h-7A.5.5 0 010 .5z" data-name="Fill 3" id="Fill_3" transform="translate(0 10)">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="Locked-Play-Button-Large" viewbox="0 0 64 64">
#     <circle cx="32" cy="32" data-name="Oval 5" fill="currentColor" id="Oval_5" r="32">
#     </circle>
#     <g data-name="Icons/Core/Lock" id="Icons_Core_Lock" transform="translate(18 17.25)">
#      <g data-name="Page 1" fill="#fff" id="Page_1" transform="translate(4 1)">
#       <path d="M20 22.5H0v-10a1.251 1.251 0 011.25-1.25h1.288a4.913 4.913 0 01-.038-.625v-3.75A6.883 6.883 0 019.375 0h1.25A6.883 6.883 0 0117.5 6.875v3.75a5.117 5.117 0 01-.038.625h1.288A1.251 1.251 0 0120 12.5v10zM9.375 3.75A3.128 3.128 0 006.25 6.875v3.75a3.458 3.458 0 00.062.625h7.375a3.46 3.46 0 00.062-.625v-3.75a3.129 3.129 0 00-3.125-3.125z" data-name="Fill 1" id="Fill_1">
#       </path>
#       <path d="M0 0h20v1.25a1.254 1.254 0 01-1.25 1.25H1.25A1.254 1.254 0 010 1.25z" data-name="Fill 3" id="Fill_3" transform="translate(0 25)">
#       </path>
#      </g>
#     </g>
#    </symbol>
#    <symbol id="Play-Button-Large" viewbox="0 0 64 64">
#     <circle cx="32" cy="32" data-name="Oval 5" fill="currentColor" id="Oval_5" r="32">
#     </circle>
#     <path d="M0 26.09V0l23 13.045z" data-name="Path 2 Copy 2" fill="#fff" id="Path_2_Copy_2" transform="translate(23.338 18.955)">
#     </path>
#    </symbol>
#    <symbol id="Gallery-Button-Large" viewbox="0 0 64 64">
#     <path d="M0 0h64v64H0z" data-name="Icons/Media/PictureSpecial background" fill="none" id="Icons_Media_PictureSpecial_background">
#     </path>
#     <circle cx="32" cy="32" data-name="Oval 5" fill="currentColor" id="Oval_5" r="32">
#     </circle>
#     <path d="M3814.479-8222a2.481 2.481 0 01-2.478-2.479v-12.814a2.479 2.479 0 012.478-2.482h6.2a2.221 2.221 0 012.223-2.225h7.959a2.223 2.223 0 012.222 2.225h6.2a2.484 2.484 0 012.484 2.482v12.814a2.486 2.486 0 01-2.484 2.479zm4.963-8.889c0 3.679 3.335 6.666 7.44 6.666s7.446-2.987 7.446-6.666-3.341-6.666-7.446-6.666-7.44 2.991-7.44 6.664zm-4.963-5.554a1.113 1.113 0 001.114 1.108h1.5a1.111 1.111 0 001.108-1.108 1.112 1.112 0 00-1.108-1.112h-1.5a1.113 1.113 0 00-1.114 1.111zm7.441 5.554a4.727 4.727 0 014.962-4.445 4.727 4.727 0 014.963 4.445 4.723 4.723 0 01-4.963 4.441 4.723 4.723 0 01-4.962-4.443z" data-name="Path 59992" fill="#fff" id="Path_59992" transform="translate(-3794.885 8264.002)">
#     </path>
#    </symbol>
#   </svg>
#   <script>
#    // if ('serviceWorker' in navigator) {
#     //   window.addEventListener('load', function() {
#     //     navigator.serviceWorker.register('/dist/service-worker.js');
#     //   });
#     // }
#
#     if ('serviceWorker' in navigator) {
#         navigator.serviceWorker.getRegistrations().then(function (registrations) {
#             registrations.forEach(function (registration) {
#                 registration.unregister();
#             })
#         });
#     }
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/3.6.1/jquery.min.js">
#   </script>
#   <script src="/dist/scripts/vendors~discussion~main~pagination-module~supporters-club~tickets.js?v=Prod_250" type="module">
#   </script>
#   <script src="/dist/scripts/vendors~discussion~main~players~supporters-club.js?v=Prod_250" type="module">
#   </script>
#   <script src="/dist/scripts/main.js?v=Prod_250" type="module">
#   </script>
#   <script nomodule="" src="/dist/scripts/vendors~discussion~fixtures~main~pagination-module~players~supporters-club~tickets.legacy.js?v=Prod_250">
#   </script>
#   <script nomodule="" src="/dist/scripts/vendors~discussion~main~players~supporters-club.legacy.js?v=Prod_250">
#   </script>
#   <script nomodule="" src="/dist/scripts/main.legacy.js?v=Prod_250">
#   </script>
#   <div class="progress-bar">
#    <img alt="loading" class="progress-bar__image" src="https://web-assets.mancity.com/dist/images/man-city-loader.gif"/>
#   </div>
#  </body>
# </html>

# %%
members = s.select('li.squad-list__item.js-card-slider-list-item')

# %%
members
# Out:
# [<li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/zack-steffen">
#  <article aria-label="Zack Steffen" class="member-card member-card--is-on-loan">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">13</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Zack Steffen" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=564&amp;quality=100 3x" title="Zack Steffen"/>
#  <img alt="Zack Steffen" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Zack Steffen"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="United States of America" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/rueglyql/us.svg" title="United States of America"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Zack</span>
#  <span class="member-card__name">Steffen</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/stefan-ortega-moreno">
#  <article aria-label="Stefan Ortega Moreno" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">18</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Stefan Ortega Moreno" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=564&amp;quality=100 3x" title="Stefan Ortega Moreno"/>
#  <img alt="Stefan Ortega Moreno" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Stefan Ortega Moreno"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Germany" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/q0omqxek/de.svg" title="Germany"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Stefan</span>
#  <span class="member-card__name">Ortega Moreno</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/ederson">
#  <article aria-label="Ederson" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">31</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Ederson" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=564&amp;quality=100 3x" title="Ederson"/>
#  <img alt="Ederson" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Ederson"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Brazil" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/1cnlvryp/br.svg" title="Brazil"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Ederson</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/scott-carson">
#  <article aria-label="Scott Carson" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">33</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Scott Carson" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/srpgqlct/scott-carson.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/srpgqlct/scott-carson.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/srpgqlct/scott-carson.png?width=564&amp;quality=100 3x" title="Scott Carson"/>
#  <img alt="Scott Carson" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Scott Carson"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Scott</span>
#  <span class="member-card__name">Carson</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/kyle-walker">
#  <article aria-label="Kyle Walker" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">2</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Kyle Walker" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/qhmhkd01/kyle-walker.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/qhmhkd01/kyle-walker.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/qhmhkd01/kyle-walker.png?width=564&amp;quality=100 3x" title="Kyle Walker"/>
#  <img alt="Kyle Walker" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Kyle Walker"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Kyle</span>
#  <span class="member-card__name">Walker</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/ruben-dias">
#  <article aria-label="Ruben Dias" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">3</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Ruben Dias" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/yowlxkfa/ruben-dias.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/yowlxkfa/ruben-dias.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/yowlxkfa/ruben-dias.png?width=564&amp;quality=100 3x" title="Ruben Dias"/>
#  <img alt="Ruben Dias" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Ruben Dias"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Portugal" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/wyuhecht/pt.svg" title="Portugal"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Ruben</span>
#  <span class="member-card__name">Dias</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/john-stones">
#  <article aria-label="John Stones" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">5</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="John Stones" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/4cicyu5v/john-stones.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/4cicyu5v/john-stones.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/4cicyu5v/john-stones.png?width=564&amp;quality=100 3x" title="John Stones"/>
#  <img alt="John Stones" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="John Stones"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">John</span>
#  <span class="member-card__name">Stones</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/nathan-ake">
#  <article aria-label="Nathan Ake" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">6</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Nathan Ake" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/oelcevzg/nathan-ake-r.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/oelcevzg/nathan-ake-r.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/oelcevzg/nathan-ake-r.png?width=564&amp;quality=100 3x" title="Nathan Ake"/>
#  <img alt="Nathan Ake" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Nathan Ake"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Netherlands" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/xv1hoqyi/nl.svg" title="Netherlands"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Nathan</span>
#  <span class="member-card__name">Ake</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/joao-cancelo">
#  <article aria-label="João Cancelo" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">7</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="João Cancelo" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/pm3b0zop/joao-cancelo.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/pm3b0zop/joao-cancelo.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/pm3b0zop/joao-cancelo.png?width=564&amp;quality=100 3x" title="João Cancelo"/>
#  <img alt="João Cancelo" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="João Cancelo"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Portugal" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/wyuhecht/pt.svg" title="Portugal"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">João</span>
#  <span class="member-card__name">Cancelo</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/aymeric-laporte">
#  <article aria-label="Aymeric Laporte" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">14</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Aymeric Laporte" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/3ccfwpn5/aymeric-laporte.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/3ccfwpn5/aymeric-laporte.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/3ccfwpn5/aymeric-laporte.png?width=564&amp;quality=100 3x" title="Aymeric Laporte"/>
#  <img alt="Aymeric Laporte" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Aymeric Laporte"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Aymeric</span>
#  <span class="member-card__name">Laporte</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/sergio-gomez">
#  <article aria-label="Sergio Gomez" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">21</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Sergio Gomez" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/2jkdz4bv/sergio-gomez-h-s-cut.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/2jkdz4bv/sergio-gomez-h-s-cut.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/2jkdz4bv/sergio-gomez-h-s-cut.png?width=564&amp;quality=100 3x" title="Sergio Gomez"/>
#  <img alt="Sergio Gomez" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Sergio Gomez"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Sergio</span>
#  <span class="member-card__name">Gomez</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/manuel-akanji">
#  <article aria-label="Manuel Akanji" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">25</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Manuel Akanji" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/akzl24xy/akanji-cut-out.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/akzl24xy/akanji-cut-out.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/akzl24xy/akanji-cut-out.png?width=564&amp;quality=100 3x" title="Manuel Akanji"/>
#  <img alt="Manuel Akanji" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Manuel Akanji"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Switzerland" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/ygdf1u0z/ch.svg" title="Switzerland"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Manuel</span>
#  <span class="member-card__name">Akanji</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/rico-lewis">
#  <article aria-label="Rico Lewis" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">82</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Rico Lewis" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/vnklmpoz/rico-lewis-v2.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/vnklmpoz/rico-lewis-v2.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/vnklmpoz/rico-lewis-v2.png?width=564&amp;quality=100 3x" title="Rico Lewis"/>
#  <img alt="Rico Lewis" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Rico Lewis"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Rico</span>
#  <span class="member-card__name">Lewis</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/joshua-wilson-esbrand">
#  <article aria-label="Joshua Wilson-Esbrand" class="member-card member-card--is-on-loan">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">97</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Joshua Wilson-Esbrand" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/zi1fk4sc/microsoftteams-image-36.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/zi1fk4sc/microsoftteams-image-36.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/zi1fk4sc/microsoftteams-image-36.png?width=564&amp;quality=100 3x" title="Joshua Wilson-Esbrand"/>
#  <img alt="Joshua Wilson-Esbrand" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Joshua Wilson-Esbrand"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Joshua</span>
#  <span class="member-card__name">Wilson-Esbrand</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/kalvin-phillips">
#  <article aria-label="Kalvin Phillips" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">4</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Kalvin Phillips" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/ptpfyzte/kalvinphillips.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/ptpfyzte/kalvinphillips.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/ptpfyzte/kalvinphillips.png?width=564&amp;quality=100 3x" title="Kalvin Phillips"/>
#  <img alt="Kalvin Phillips" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Kalvin Phillips"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Kalvin</span>
#  <span class="member-card__name">Phillips</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/ilkay-gundogan">
#  <article aria-label="Ilkay Gundogan" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">8</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Ilkay Gundogan" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/cnek0jbq/ilkay-gundogan.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/cnek0jbq/ilkay-gundogan.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/cnek0jbq/ilkay-gundogan.png?width=564&amp;quality=100 3x" title="Ilkay Gundogan"/>
#  <img alt="Ilkay Gundogan" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Ilkay Gundogan"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Germany" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/q0omqxek/de.svg" title="Germany"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Ilkay</span>
#  <span class="member-card__name">Gundogan</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/jack-grealish">
#  <article aria-label="Jack Grealish" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">10</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Jack Grealish" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/qdlbnbg2/jack-grealish.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/qdlbnbg2/jack-grealish.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/qdlbnbg2/jack-grealish.png?width=564&amp;quality=100 3x" title="Jack Grealish"/>
#  <img alt="Jack Grealish" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Jack Grealish"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Jack</span>
#  <span class="member-card__name">Grealish</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/rodrigo">
#  <article aria-label="Rodrigo" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">16</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Rodrigo" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/a5rpno0p/rodri.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/a5rpno0p/rodri.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/a5rpno0p/rodri.png?width=564&amp;quality=100 3x" title="Rodrigo"/>
#  <img alt="Rodrigo" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Rodrigo"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Rodrigo</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/kevin-de-bruyne">
#  <article aria-label="Kevin De Bruyne" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">17</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Kevin De Bruyne" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/4jeo4c53/kevin-de-bruyne.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/4jeo4c53/kevin-de-bruyne.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/4jeo4c53/kevin-de-bruyne.png?width=564&amp;quality=100 3x" title="Kevin De Bruyne"/>
#  <img alt="Kevin De Bruyne" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Kevin De Bruyne"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Belgium" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/2naltqhs/be.svg" title="Belgium"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Kevin</span>
#  <span class="member-card__name">De Bruyne</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/bernardo-silva">
#  <article aria-label="Bernardo Silva" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">20</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Bernardo Silva" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/idanln53/bernardo-silva.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/idanln53/bernardo-silva.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/idanln53/bernardo-silva.png?width=564&amp;quality=100 3x" title="Bernardo Silva"/>
#  <img alt="Bernardo Silva" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Bernardo Silva"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Portugal" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/wyuhecht/pt.svg" title="Portugal"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Bernardo</span>
#  <span class="member-card__name">Silva</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/phil-foden">
#  <article aria-label="Phil Foden" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">47</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Phil Foden" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/2ozp4m04/phil-foden.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/2ozp4m04/phil-foden.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/2ozp4m04/phil-foden.png?width=564&amp;quality=100 3x" title="Phil Foden"/>
#  <img alt="Phil Foden" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Phil Foden"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Phil</span>
#  <span class="member-card__name">Foden</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/cole-palmer">
#  <article aria-label="Cole Palmer" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">80</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Cole Palmer" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/k12mpj0o/cole-palmer.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/k12mpj0o/cole-palmer.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/k12mpj0o/cole-palmer.png?width=564&amp;quality=100 3x" title="Cole Palmer"/>
#  <img alt="Cole Palmer" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Cole Palmer"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="England" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/kbujcobi/gb-eng.svg" title="England"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Cole</span>
#  <span class="member-card__name">Palmer</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/erling-haaland">
#  <article aria-label="Erling Haaland" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">9</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Erling Haaland" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/233jlh2j/microsoftteams-image-127.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/233jlh2j/microsoftteams-image-127.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/233jlh2j/microsoftteams-image-127.png?width=564&amp;quality=100 3x" title="Erling Haaland"/>
#  <img alt="Erling Haaland" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Erling Haaland"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Norway" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/tollp40b/no.svg" title="Norway"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Erling</span>
#  <span class="member-card__name">Haaland</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/julian-alvarez">
#  <article aria-label="Julian Alvarez" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">19</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Julian Alvarez" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/ptfh0hca/julian-alvarez.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/ptfh0hca/julian-alvarez.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/ptfh0hca/julian-alvarez.png?width=564&amp;quality=100 3x" title="Julian Alvarez"/>
#  <img alt="Julian Alvarez" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Julian Alvarez"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Argentina" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/2kuefji1/ar.svg" title="Argentina"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Julian</span>
#  <span class="member-card__name">Alvarez</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/riyad-mahrez">
#  <article aria-label="Riyad Mahrez" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">26</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Riyad Mahrez" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/3mjhpfve/riyad-mahrez.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/3mjhpfve/riyad-mahrez.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/3mjhpfve/riyad-mahrez.png?width=564&amp;quality=100 3x" title="Riyad Mahrez"/>
#  <img alt="Riyad Mahrez" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Riyad Mahrez"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Algeria" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/tpik1kes/dz.svg" title="Algeria"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Riyad</span>
#  <span class="member-card__name">Mahrez</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/pep-guardiola">
#  <article aria-label="Pep Guardiola" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Pep Guardiola" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/1jdgzaax/pep-guardiola.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/1jdgzaax/pep-guardiola.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/1jdgzaax/pep-guardiola.png?width=564&amp;quality=100 3x" title="Pep Guardiola"/>
#  <img alt="Pep Guardiola" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Pep Guardiola"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Pep</span>
#  <span class="member-card__name">Guardiola</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#   </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/rodolfo-borrell">
#  <article aria-label="Rodolfo Borrell" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Rodolfo Borrell" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/g1gjtkbf/rodolfo-borrell.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/g1gjtkbf/rodolfo-borrell.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/g1gjtkbf/rodolfo-borrell.png?width=564&amp;quality=100 3x" title="Rodolfo Borrell"/>
#  <img alt="Rodolfo Borrell" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Rodolfo Borrell"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Rodolfo</span>
#  <span class="member-card__name">Borrell</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/lorenzo-buenaventura">
#  <article aria-label="Lorenzo Buenaventura" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Lorenzo Buenaventura" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/0pvlbb1w/lorenzo-buenaventura.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/0pvlbb1w/lorenzo-buenaventura.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/0pvlbb1w/lorenzo-buenaventura.png?width=564&amp;quality=100 3x" title="Lorenzo Buenaventura"/>
#  <img alt="Lorenzo Buenaventura" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Lorenzo Buenaventura"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Lorenzo</span>
#  <span class="member-card__name">Buenaventura</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/manel-estiarte">
#  <article aria-label="Manel Estiarte" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Manel Estiarte" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/tlzh12v2/manel-estiarte.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/tlzh12v2/manel-estiarte.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/tlzh12v2/manel-estiarte.png?width=564&amp;quality=100 3x" title="Manel Estiarte"/>
#  <img alt="Manel Estiarte" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Manel Estiarte"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Manel</span>
#  <span class="member-card__name">Estiarte</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/xabier-mancisidor">
#  <article aria-label="Xabier Mancisidor" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Xabier Mancisidor" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/pjch0jmo/xabier-mancisidor.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/pjch0jmo/xabier-mancisidor.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/pjch0jmo/xabier-mancisidor.png?width=564&amp;quality=100 3x" title="Xabier Mancisidor"/>
#  <img alt="Xabier Mancisidor" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Xabier Mancisidor"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Xabier</span>
#  <span class="member-card__name">Mancisidor</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/enzo-maresca">
#  <article aria-label="Enzo Maresca" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Enzo Maresca" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/kqzk5w1d/enzo-maresca.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/kqzk5w1d/enzo-maresca.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/kqzk5w1d/enzo-maresca.png?width=564&amp;quality=100 3x" title="Enzo Maresca"/>
#  <img alt="Enzo Maresca" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Enzo Maresca"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Italy" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/cztjrjms/it.svg" title="Italy"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Enzo</span>
#  <span class="member-card__name">Maresca</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/carles-planchart">
#  <article aria-label="Carles Planchart" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Carles Planchart" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/qqcj3lsg/carles-planchart.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/qqcj3lsg/carles-planchart.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/qqcj3lsg/carles-planchart.png?width=564&amp;quality=100 3x" title="Carles Planchart"/>
#  <img alt="Carles Planchart" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Carles Planchart"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Spain" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/34sj50z3/es.svg" title="Spain"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Carles</span>
#  <span class="member-card__name">Planchart</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/carlos-vicens">
#  <article aria-label="Carlos Vicens" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Carlos Vicens" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/tzbnvvvv/carlos-vicens.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/tzbnvvvv/carlos-vicens.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/tzbnvvvv/carlos-vicens.png?width=564&amp;quality=100 3x" title="Carlos Vicens"/>
#  <img alt="Carlos Vicens" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Carlos Vicens"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Carlos</span>
#  <span class="member-card__name">Vicens</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/richard-wright">
#  <article aria-label="Richard Wright" class="member-card member-card--is-manager">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <div class="member-card__photo-wrapper">
#  <img alt="Richard Wright" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/ukchhz05/richard-wright.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/ukchhz05/richard-wright.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/ukchhz05/richard-wright.png?width=564&amp;quality=100 3x" title="Richard Wright"/>
#  <img alt="Richard Wright" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Richard Wright"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Richard</span>
#  <span class="member-card__name">Wright</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>]

# %%
len(members)
# Out:
# 34

# %%
members[0]
# Out:
# <li class="squad-list__item js-card-slider-list-item">
# <a class="squad-list__item-link" href="/players/zack-steffen">
# <article aria-label="Zack Steffen" class="member-card member-card--is-on-loan">
# <div class="member-card__header">
# <div class="member-card__on-loan-badge">
# <span class="badge-text">
# On loan
# </span>
# </div>
# <span class="member-card__shirt-number">13</span>
# <div class="member-card__photo-wrapper">
# <img alt="Zack Steffen" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=564&amp;quality=100 3x" title="Zack Steffen"/>
# <img alt="Zack Steffen" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Zack Steffen"/>
# </div>
# <div class="member-card__country-flag-wrapper">
# <img alt="United States of America" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/rueglyql/us.svg" title="United States of America"/>
# </div>
# </div>
# <div class="member-card__content">
# <h3 class="member-card__full-name">
# <span class="member-card__name">Zack</span>
# <span class="member-card__name">Steffen</span>
# </h3>
# <div class="member-card__captain-badge">
# <span class="badge-text" title="Captain">
# C
# </span>
# </div>
# </div>
# <div class="member-card__regular-shadow"></div>
# <div class="member-card__active-shadow"></div>
# </article>
# </a>
# </li>

# %%
members[0].select_one('a')
# Out:
# <a class="squad-list__item-link" href="/players/zack-steffen">
# <article aria-label="Zack Steffen" class="member-card member-card--is-on-loan">
# <div class="member-card__header">
# <div class="member-card__on-loan-badge">
# <span class="badge-text">
# On loan
# </span>
# </div>
# <span class="member-card__shirt-number">13</span>
# <div class="member-card__photo-wrapper">
# <img alt="Zack Steffen" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=564&amp;quality=100 3x" title="Zack Steffen"/>
# <img alt="Zack Steffen" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Zack Steffen"/>
# </div>
# <div class="member-card__country-flag-wrapper">
# <img alt="United States of America" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/rueglyql/us.svg" title="United States of America"/>
# </div>
# </div>
# <div class="member-card__content">
# <h3 class="member-card__full-name">
# <span class="member-card__name">Zack</span>
# <span class="member-card__name">Steffen</span>
# </h3>
# <div class="member-card__captain-badge">
# <span class="badge-text" title="Captain">
# C
# </span>
# </div>
# </div>
# <div class="member-card__regular-shadow"></div>
# <div class="member-card__active-shadow"></div>
# </article>
# </a>

# %%
members[0].select_one('a')['href']
# Out:
# '/players/zack-steffen'

# %%
members[0].select_one('span.member-card__shirt-number')
# Out:
# <span class="member-card__shirt-number">13</span>

# %%
members[0].select_one('span.member-card__shirt-number').text
# Out:
# '13'

# %%
members[0].select_one('h3.member-card__full-name')
# Out:
# <h3 class="member-card__full-name">
# <span class="member-card__name">Zack</span>
# <span class="member-card__name">Steffen</span>
# </h3>

# %%
members[0].select_one('h3.member-card__full-name').text
# Out:
# '\nZack\nSteffen\n'

# %%
members[0].select_one('h3.member-card__full-name').select('span')[0].text
# Out:
# 'Zack'

# %%
members[0].select_one('h3.member-card__full-name').select('span')[1].text
# Out:
# 'Steffen'

# %%
members[0]
# Out:
# <li class="squad-list__item js-card-slider-list-item">
# <a class="squad-list__item-link" href="/players/zack-steffen">
# <article aria-label="Zack Steffen" class="member-card member-card--is-on-loan">
# <div class="member-card__header">
# <div class="member-card__on-loan-badge">
# <span class="badge-text">
# On loan
# </span>
# </div>
# <span class="member-card__shirt-number">13</span>
# <div class="member-card__photo-wrapper">
# <img alt="Zack Steffen" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=564&amp;quality=100 3x" title="Zack Steffen"/>
# <img alt="Zack Steffen" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Zack Steffen"/>
# </div>
# <div class="member-card__country-flag-wrapper">
# <img alt="United States of America" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/rueglyql/us.svg" title="United States of America"/>
# </div>
# </div>
# <div class="member-card__content">
# <h3 class="member-card__full-name">
# <span class="member-card__name">Zack</span>
# <span class="member-card__name">Steffen</span>
# </h3>
# <div class="member-card__captain-badge">
# <span class="badge-text" title="Captain">
# C
# </span>
# </div>
# </div>
# <div class="member-card__regular-shadow"></div>
# <div class="member-card__active-shadow"></div>
# </article>
# </a>
# </li>

# %%
members[0].select_one('img')
# Out:
# <img alt="Zack Steffen" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=564&amp;quality=100 3x" title="Zack Steffen"/>

# %%
type(members[0].select_one('img'))
# Out:
# bs4.element.Tag

# %%
members[0].select_one('img')['alt']
# Out:
# 'Zack Steffen'

# %%
members[0].select_one('img')['alt'].split(' ')
# Out:
# ['Zack', 'Steffen']

# %%
members[0].select_one('img')['src']
# Out:
# 'https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100'

# %%
r1 = requests.get(members[10].select_one('img')['src'])
img = Image.open(io.BytesIO(r1.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=376x376>

# %%
members[0:3]
# Out:
# [<li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/zack-steffen">
#  <article aria-label="Zack Steffen" class="member-card member-card--is-on-loan">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">13</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Zack Steffen" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=564&amp;quality=100 3x" title="Zack Steffen"/>
#  <img alt="Zack Steffen" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Zack Steffen"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="United States of America" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/rueglyql/us.svg" title="United States of America"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Zack</span>
#  <span class="member-card__name">Steffen</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/stefan-ortega-moreno">
#  <article aria-label="Stefan Ortega Moreno" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">18</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Stefan Ortega Moreno" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=564&amp;quality=100 3x" title="Stefan Ortega Moreno"/>
#  <img alt="Stefan Ortega Moreno" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Stefan Ortega Moreno"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Germany" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/q0omqxek/de.svg" title="Germany"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Stefan</span>
#  <span class="member-card__name">Ortega Moreno</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>,
#  <li class="squad-list__item js-card-slider-list-item">
#  <a class="squad-list__item-link" href="/players/ederson">
#  <article aria-label="Ederson" class="member-card">
#  <div class="member-card__header">
#  <div class="member-card__on-loan-badge">
#  <span class="badge-text">
#  On loan
#  </span>
#  </div>
#  <span class="member-card__shirt-number">31</span>
#  <div class="member-card__photo-wrapper">
#  <img alt="Ederson" class="member-card__photo" onerror="markAsImgLoadFailed(this)" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&amp;quality=100" srcset="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&amp;quality=100 2x, https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=564&amp;quality=100 3x" title="Ederson"/>
#  <img alt="Ederson" class="member-card__photo fallback-player-image" src="/dist/images/half_body.png" title="Ederson"/>
#  </div>
#  <div class="member-card__country-flag-wrapper">
#  <img alt="Brazil" class="member-card__country-flag" src="https://mediacdn.mancity.com/meta/media/1cnlvryp/br.svg" title="Brazil"/>
#  </div>
#  </div>
#  <div class="member-card__content">
#  <h3 class="member-card__full-name">
#  <span class="member-card__name">Ederson</span>
#  </h3>
#  <div class="member-card__captain-badge">
#  <span class="badge-text" title="Captain">
#  C
#  </span>
#  </div>
#  </div>
#  <div class="member-card__regular-shadow"></div>
#  <div class="member-card__active-shadow"></div>
#  </article>
#  </a>
#  </li>]

# %%
lst=[]
for e in members[:3]:
#for e in members:
    mem_img_url = e.select_one('img')['src']
    mem_name = e.select_one('img')['alt']
    mem_number = e.select_one('span.member-card__shirt-number').text
    mem_link = f"https://www.mancity.com{e.select_one('a')['href']}"
    print(f'{mem_name} {mem_number} {mem_img_url} {mem_link}')
    lst.append([mem_name, mem_number, mem_img_url, mem_link])
#   r=requests.get(mem_img_url)
#   img=Image.open(io.BytesIO(r.content))
#   save_img(f'{mem_name}_{mem_number}.jpg', r.content)
#   img.show()
lst[:3]
# Out:
# Zack Steffen 13 https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100 https://www.mancity.com/players/zack-steffen
# Stefan Ortega Moreno 18 https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100 https://www.mancity.com/players/stefan-ortega-moreno
# Ederson 31 https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100 https://www.mancity.com/players/ederson
# [['Zack Steffen',
#   '13',
#   'https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100',
#   'https://www.mancity.com/players/zack-steffen'],
#  ['Stefan Ortega Moreno',
#   '18',
#   'https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100',
#   'https://www.mancity.com/players/stefan-ortega-moreno'],
#  ['Ederson',
#   '31',
#   'https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100',
#   'https://www.mancity.com/players/ederson']]

# %%
pd.options.display.max_colwidth = 0

# %%
df=pd.DataFrame(lst, columns=['name', 'number', 'img_url', 'link'])
df.head()
# Out:
#                    name number  \
# 0  Zack Steffen          13
# 1  Stefan Ortega Moreno  18
# 2  Ederson               31
#
#                                                                                       img_url  \
# 0  https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100
# 1  https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100
# 2  https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100
#
#                                                    link
# 0  https://www.mancity.com/players/zack-steffen
# 1  https://www.mancity.com/players/stefan-ortega-moreno
# 2  https://www.mancity.com/players/ederson

# %%
from IPython.display import HTML

# %%
def to_html_img(url, alt=None, width=100):
    if alt==None:
        alt=''
    return f'<img alt="{alt}" src="{url}" width="{width}"/>'

# %%
to_html_img('https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/33/thumb_132595_misc_general_500.jpeg')
# Out:
# '<img alt="" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0002/33/thumb_132595_misc_general_500.jpeg" width="100"/>'

# %%
df['img']=df.apply(lambda r: to_html_img(r['img_url'],r['name'], 100), axis=1)
df.head()
#add column image as html file
# Out:
#                    name number  \
# 0  Zack Steffen          13
# 1  Stefan Ortega Moreno  18
# 2  Ederson               31
#
#                                                                                       img_url  \
# 0  https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100
# 1  https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100
# 2  https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100
#
#                                                    link  \
# 0  https://www.mancity.com/players/zack-steffen
# 1  https://www.mancity.com/players/stefan-ortega-moreno
# 2  https://www.mancity.com/players/ederson
#
#                                                                                                                                               img
# 0  <img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/>
# 1  <img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/>
# 2  <img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/>

# %%
HTML(df[:3][['name', 'number', 'img']].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>number</th>
#       <th>img</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Zack Steffen</td>
#       <td>13</td>
#       <td><img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Stefan Ortega Moreno</td>
#       <td>18</td>
#       <td><img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ederson</td>
#       <td>31</td>
#       <td><img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/></td>
#     </tr>
#   </tbody>
# </table>

# %%
#to create link/hyperlink
def to_html_a(url, text): #a is reference as text 
    if text==None:
        text=''
    return f'<a href="{url}">{text}</a'

# %%
to_html_a('https://www.liverpoolfc.com/team/first-team/player/alisson-becker', '<img alt="" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69996_misc_general_500.jpeg" width="100"/>')
# Out:
# '<a href="https://www.liverpoolfc.com/team/first-team/player/alisson-becker"><img alt="" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69996_misc_general_500.jpeg" width="100"/></a'

# %%
#hyperlink with name
df['a']=df.apply(lambda r: to_html_a(r['link'],r['name']), axis=1)
df.head()
# Out:
#                    name number  \
# 0  Zack Steffen          13
# 1  Stefan Ortega Moreno  18
# 2  Ederson               31
#
#                                                                                       img_url  \
# 0  https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100
# 1  https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100
# 2  https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100
#
#                                                    link  \
# 0  https://www.mancity.com/players/zack-steffen
# 1  https://www.mancity.com/players/stefan-ortega-moreno
# 2  https://www.mancity.com/players/ederson
#
#                                                                                                                                               img  \
# 0  <img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/>
# 1  <img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/>
# 2  <img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/>
#
#                                                                                         a
# 0  <a href="https://www.mancity.com/players/zack-steffen">Zack Steffen</a
# 1  <a href="https://www.mancity.com/players/stefan-ortega-moreno">Stefan Ortega Moreno</a
# 2  <a href="https://www.mancity.com/players/ederson">Ederson</a

# %%
HTML(df[:3][['name','number','img', 'a']].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>number</th>
#       <th>img</th>
#       <th>a</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Zack Steffen</td>
#       <td>13</td>
#       <td><img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/></td>
#       <td><a href="https://www.mancity.com/players/zack-steffen">Zack Steffen</a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Stefan Ortega Moreno</td>
#       <td>18</td>
#       <td><img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/></td>
#       <td><a href="https://www.mancity.com/players/stefan-ortega-moreno">Stefan Ortega Moreno</a</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ederson</td>
#       <td>31</td>
#       <td><img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/></td>
#       <td><a href="https://www.mancity.com/players/ederson">Ederson</a</td>
#     </tr>
#   </tbody>
# </table>

# %%
#hyperlink with image
df['a2']=df.apply(lambda r: to_html_a(r['link'],r['img']), axis=1)
df.head()
# Out:
#                    name number  \
# 0  Zack Steffen          13
# 1  Stefan Ortega Moreno  18
# 2  Ederson               31
#
#                                                                                       img_url  \
# 0  https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100
# 1  https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100
# 2  https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100
#
#                                                    link  \
# 0  https://www.mancity.com/players/zack-steffen
# 1  https://www.mancity.com/players/stefan-ortega-moreno
# 2  https://www.mancity.com/players/ederson
#
#                                                                                                                                               img  \
# 0  <img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/>
# 1  <img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/>
# 2  <img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/>
#
#                                                                                         a  \
# 0  <a href="https://www.mancity.com/players/zack-steffen">Zack Steffen</a
# 1  <a href="https://www.mancity.com/players/stefan-ortega-moreno">Stefan Ortega Moreno</a
# 2  <a href="https://www.mancity.com/players/ederson">Ederson</a
#
#                                                                                                                                                                                                                  a2
# 0  <a href="https://www.mancity.com/players/zack-steffen"><img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/></a
# 1  <a href="https://www.mancity.com/players/stefan-ortega-moreno"><img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/></a
# 2  <a href="https://www.mancity.com/players/ederson"><img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/></a

# %%
HTML(df[:3][['number','a', 'a2']].to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>number</th>
#       <th>a</th>
#       <th>a2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13</td>
#       <td><a href="https://www.mancity.com/players/zack-steffen">Zack Steffen</a</td>
#       <td><a href="https://www.mancity.com/players/zack-steffen"><img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/></a</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td><a href="https://www.mancity.com/players/stefan-ortega-moreno">Stefan Ortega Moreno</a</td>
#       <td><a href="https://www.mancity.com/players/stefan-ortega-moreno"><img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/></a</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>31</td>
#       <td><a href="https://www.mancity.com/players/ederson">Ederson</a</td>
#       <td><a href="https://www.mancity.com/players/ederson"><img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/></a</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Save Dataframe

# %%
df.to_csv('Man_City.csv', index=False)

# %%
from sqlalchemy import create_engine
con = create_engine(f'sqlite:///Man_City.sqlite')
df.to_sql('player', con, if_exists='replace', index=False)
# Out:
# 3

# %%
pd.read_sql('select * from player limit 3;', con)
# Out:
#                    name number  \
# 0  Zack Steffen          13
# 1  Stefan Ortega Moreno  18
# 2  Ederson               31
#
#                                                                                       img_url  \
# 0  https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100
# 1  https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100
# 2  https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100
#
#                                                    link  \
# 0  https://www.mancity.com/players/zack-steffen
# 1  https://www.mancity.com/players/stefan-ortega-moreno
# 2  https://www.mancity.com/players/ederson
#
#                                                                                                                                               img  \
# 0  <img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/>
# 1  <img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/>
# 2  <img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/>
#
#                                                                                         a  \
# 0  <a href="https://www.mancity.com/players/zack-steffen">Zack Steffen</a
# 1  <a href="https://www.mancity.com/players/stefan-ortega-moreno">Stefan Ortega Moreno</a
# 2  <a href="https://www.mancity.com/players/ederson">Ederson</a
#
#                                                                                                                                                                                                                  a2
# 0  <a href="https://www.mancity.com/players/zack-steffen"><img alt="Zack Steffen" src="https://www.mancity.com/meta/media/z2oodjhx/zack-steffen.png?width=376&quality=100" width="100"/></a
# 1  <a href="https://www.mancity.com/players/stefan-ortega-moreno"><img alt="Stefan Ortega Moreno" src="https://www.mancity.com/meta/media/105fxdow/stefan-ortega-moreno.png?width=376&quality=100" width="100"/></a
# 2  <a href="https://www.mancity.com/players/ederson"><img alt="Ederson" src="https://www.mancity.com/meta/media/xg0cuprp/ederson.png?width=376&quality=100" width="100"/></a
